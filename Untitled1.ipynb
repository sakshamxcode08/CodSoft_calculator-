# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshamxcode08/CodSoft_calculator-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
lst = ['Greek','For', 'Greek', 'is', 'portal', 'for', 'Greek']
df=pd. DataFrame(lst)
print (df)
# Out:
#         0
# 0   Greek
# 1     For
# 2   Greek
# 3      is
# 4  portal
# 5     for
# 6   Greek

# %%
import statistics
import math

data = [10, 20, 20, 30, 40]

mean = statistics.mean(data)
median = statistics.median(data)
mode = statistics.mode(data)
variance = statistics.variance(data)
std_dev = math.sqrt(variance)

print("Mean =", mean)
print("Median =", median)
print("Mode =", mode)
print("Variance =", variance)
print("Standard Deviation =", std_dev)
# Out:
# Mean = 24
# Median = 20
# Mode = 20
# Variance = 130
# Standard Deviation = 11.40175425099138

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6])

# Sum and Mean
print("Sum =", np.sum(arr))
print("Mean =", np.mean(arr))

# Maximum and Minimum
print("Maximum =", np.max(arr))
print("Minimum =", np.min(arr))

# Reshape array
reshaped = arr.reshape(2, 3)
print("Reshaped Array:\n", reshaped)

# Element-wise multiplication
print("Element-wise Multiplication:\n", arr * arr)

# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# Addition
print("Addition:\n", A + B)

# Subtraction
print("Subtraction:\n", A - B)

# Matrix Multiplication
print("Matrix Multiplication:\n", np.dot(A, B))

# Transpose
print("Transpose of A:\n", A.T)

# %%
import numpy as np

arr = np.random.rand(10)

print("Array =", arr)
print("Mean =", np.mean(arr))
print("Standard Deviation =", np.std(arr))
print("Minimum =", np.min(arr))
print("Maximum =", np.max(arr))

# %%
from scipy import stats

data = [10, 12, 14, 16, 18]

# Mean using scipy
mean = stats.tmean(data)
print("Mean =", mean)

# T-test
sample1 = [10, 12, 14, 16, 18]
sample2 = [11, 13, 15, 17, 19]

t_stat, p_value = stats.ttest_ind(sample1, sample2)
print("T-statistic =", t_stat)
print("P-value =", p_value)

# %%
from scipy import integrate

def func(x):
    return x**2

result, error = integrate.quad(func, 0, 1)

print("Integration Result =", result)

# %%
from scipy import optimize

def func(x):
    return x**2 + 4*x + 4

result = optimize.minimize(func, x0=0)

print("Minimum Value =", result.fun)
print("At x =", result.x)
